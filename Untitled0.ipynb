# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHWIK111S/ISE/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("glologics")

# %%
print(1)

# %%
print(1w)

# %%
print("name :Sathwik S Devadiga")
print("Age:",20)
print("College name:Sahyadri college of engineering and management")
print("year:2nd")
print("Branch:ISE")
# Out:
# name :Sathwik S Devadiga
# Age: 20
# College name:Sahyadri college of engineering and management
# year:2nd
# Branch:ISE
